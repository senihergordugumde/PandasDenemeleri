# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
data = pd.read_html("https://www.eurosport.com.tr/futbol/super-lig/puandurumu.shtml", header = 0)[0]

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2               Takımlar  Son maçlar   P  \
# 0          NaN           1         NaN         GalatasarayGAL         NaN  25
# 1          NaN           2         NaN          FenerbahçeFEN         NaN  24
# 2          NaN           3         NaN            BeşiktaşBES         NaN  25
# 3          NaN           4         NaN     Adana DemirsporADE         NaN  25
# 4          NaN           5         NaN          TrabzonsporTS         NaN  25
# 5          NaN           6         NaN          BaşakşehirBAS         NaN  24
# 6          NaN           7         NaN         KayserisporKAY         NaN  25
# 7          NaN           8         NaN           KonyasporKON         NaN  25
# 8          NaN           9         NaN    Fatih KaragümrükKAR         NaN  24
# 9          NaN          10         NaN         AntalyasporANT         NaN  25
# 10         NaN          11         NaN  Aytemiz AlanyasporALA         NaN  25
# ...

# %%
data.drop(columns = ["Unnamed: 0", "Unnamed: 1", "Unnamed: 2", "Son maçlar", "Unnamed: 13"])
# Out:
#                  Takımlar   P   K   B   L   H  KG  +/-  Puan
# 0          GalatasarayGAL  25  19   3   3  52  19   33    60
# 1           FenerbahçeFEN  24  17   3   4  61  26   35    54
# 2             BeşiktaşBES  25  14   7   4  45  25   20    49
# 3      Adana DemirsporADE  25  12   9   4  47  27   20    45
# 4           TrabzonsporTS  25  13   5   7  42  32   10    44
# 5           BaşakşehirBAS  24  12   5   7  34  26    8    41
# 6          KayserisporKAY  25  12   2  11  39  36    3    38
# 7            KonyasporKON  25   8  10   7  29  27    2    34
# 8     Fatih KaragümrükKAR  24   7  10   7  51  47    4    31
# 9          AntalyasporANT  25   8   4  13  32  40   -8    28
# 10  Aytemiz AlanyasporALA  25   7   7  11  35  46  -11    28
# 11           SivassporSIV  25   7   6  12  31  38   -7    27
# 12           KasımpaşaKAS  25   7   5  13  31  44  -13    26
# 13        Gaziantep FKGAZ  25   6   7  12  31  39   -8    25
# ...
